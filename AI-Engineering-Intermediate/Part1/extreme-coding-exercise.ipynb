# %% [markdown]
# # Write 10 lines of code that represent the ChatCompletions API
#
# import os
# from openai import OpenAI
# from dot_env import load_env
#
#
#
# if OPENAI_API_KEY is None:
#     raise("API key is not set")
#
# client = OpenAI(OPENAI_API_KEY)
# ()
# response = client.chat.completions.create(
#     model = "gpt-4-mini",
#     messages = [{"role": "system", "content": "You are a helpful assistant!"},{"role": "assistant": "How can I help you today?"}, {"role": "user", "content": "Whats the weather?"}]
# )
#
# print(response.choices[0].messages.content)
